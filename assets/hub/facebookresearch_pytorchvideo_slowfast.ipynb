# %% [markdown]
# <a href="https://colab.research.google.com/github/dralmadani/learning/blob/main/assets/hub/facebookresearch_pytorchvideo_slowfast.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from prettytable import PrettyTable

def count_parameters(model):
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad: continue
        params = parameter.numel()
        table.add_row([name, params])
        total_params+=params
    print(table)
    print(f"Total Trainable Params: {total_params}")
    return total_params

# %% [markdown]
# # SlowFast
#
# *Author: FAIR PyTorchVideo*
#
# **SlowFast networks pretrained on the Kinetics 400 dataset**
#
#
# ### Example Usage
#
# #### Imports
#
# Load the model:

# %%
# !pip install fvcore
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fvcore
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 KB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from fvcore) (1.21.6)
# Collecting yacs>=0.1.6
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from fvcore) (6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from fvcore) (4.64.1)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.8/dist-packages (from fvcore) (2.2.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.8/dist-packages (from fvcore) (7.1.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.8/dist-packages (from fvcore) (0.8.10)
# Collecting iopath>=0.1.7
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 KB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.8/dist-packages (from iopath>=0.1.7->fvcore) (4.4.0)
# Collecting portalocker
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Building wheels for collected packages: fvcore, iopath
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61431 sha256=4a9dbca487c2a2fc6146263e190ea9595e91506c65652d3bab02fca61a95faec
#   Stored in directory: /root/.cache/pip/wheels/b8/79/07/c0e9367f5b5ea325e246bd73651e8af175fabbef943043b1cc
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31547 sha256=1f89e4f3304aea2b36c0ea45093c1d8e8ebd43968d16838851a4d8c0cc22fccd
#   Stored in directory: /root/.cache/pip/wheels/89/3e/24/0f349c0b2eeb6965903035f3b00dbb5c9bea437b4a2f18d82c
# Successfully built fvcore iopath
# Installing collected packages: yacs, portalocker, iopath, fvcore
# Successfully installed fvcore-0.1.5.post20221221 iopath-0.1.10 portalocker-2.7.0 yacs-0.1.8

# %%
import torch
# Choose the `slowfast_r50` model 
model = torch.hub.load('facebookresearch/pytorchvideo', 'slowfast_r50', pretrained=True)
# Out:
# Downloading: "https://github.com/facebookresearch/pytorchvideo/zipball/main" to /root/.cache/torch/hub/main.zip
# Downloading: "https://dl.fbaipublicfiles.com/pytorchvideo/model_zoo/kinetics/SLOWFAST_8x8_R50.pyth" to /root/.cache/torch/hub/checkpoints/SLOWFAST_8x8_R50.pyth
#   0%|          | 0.00/264M [00:00<?, ?B/s]

# %%
# Total Trainable Params: 34566488
# 34566488
# Total Trainable Params: 34566488

count_parameters(model)
# Out:
# +-------------------------------------------------------------------+------------+
# |                              Modules                              | Parameters |
# +-------------------------------------------------------------------+------------+
# |             blocks.0.multipathway_blocks.0.conv.weight            |    9408    |
# |             blocks.0.multipathway_blocks.0.norm.weight            |     64     |
# |              blocks.0.multipathway_blocks.0.norm.bias             |     64     |
# |             blocks.0.multipathway_blocks.1.conv.weight            |    5880    |
# |             blocks.0.multipathway_blocks.1.norm.weight            |     8      |
# |              blocks.0.multipathway_blocks.1.norm.bias             |     8      |
# |       blocks.0.multipathway_fusion.conv_fast_to_slow.weight       |    896     |
# |              blocks.0.multipathway_fusion.norm.weight             |     16     |
# |               blocks.0.multipathway_fusion.norm.bias              |     16     |
# |  blocks.1.multipathway_blocks.0.res_blocks.0.branch1_conv.weight  |   20480    |
# |  blocks.1.multipathway_blocks.0.res_blocks.0.branch1_norm.weight  |    256     |
# |   blocks.1.multipathway_blocks.0.res_blocks.0.branch1_norm.bias   |    256     |
# | blocks.1.multipathway_blocks.0.res_blocks.0.branch2.conv_a.weight |    5120    |
# | blocks.1.multipathway_blocks.0.res_blocks.0.branch2.norm_a.weight |     64     |
# |  blocks.1.multipathway_blocks.0.res_blocks.0.branch2.norm_a.bias  |     64     |
# | blocks.1.multipathway_blocks.0.res_blocks.0.branch2.conv_b.weight |   36864    |
# | blocks.1.multipathway_blocks.0.res_blocks.0.branch2.norm_b.weight |     64     |
# |  blocks.1.multipathway_blocks.0.res_blocks.0.branch2.norm_b.bias  |     64     |
# | blocks.1.multipathway_blocks.0.res_blocks.0.branch2.conv_c.weight |   16384    |
# | blocks.1.multipathway_blocks.0.res_blocks.0.branch2.norm_c.weight |    256     |
# |  blocks.1.multipathway_blocks.0.res_blocks.0.branch2.norm_c.bias  |    256     |
# | blocks.1.multipathway_blocks.0.res_blocks.1.branch2.conv_a.weight |   16384    |
# | blocks.1.multipathway_blocks.0.res_blocks.1.branch2.norm_a.weight |     64     |
# |  blocks.1.multipathway_blocks.0.res_blocks.1.branch2.norm_a.bias  |     64     |
# | blocks.1.multipathway_blocks.0.res_blocks.1.branch2.conv_b.weight |   36864    |
# | blocks.1.multipathway_blocks.0.res_blocks.1.branch2.norm_b.weight |     64     |
# |  blocks.1.multipathway_blocks.0.res_blocks.1.branch2.norm_b.bias  |     64     |
# | blocks.1.multipathway_blocks.0.res_blocks.1.branch2.conv_c.weight |   16384    |
# | blocks.1.multipathway_blocks.0.res_blocks.1.branch2.norm_c.weight |    256     |
# |  blocks.1.multipathway_blocks.0.res_blocks.1.branch2.norm_c.bias  |    256     |
# | blocks.1.multipathway_blocks.0.res_blocks.2.branch2.conv_a.weight |   16384    |
# | blocks.1.multipathway_blocks.0.res_blocks.2.branch2.norm_a.weight |     64     |
# |  blocks.1.multipathway_blocks.0.res_blocks.2.branch2.norm_a.bias  |     64     |
# | blocks.1.multipathway_blocks.0.res_blocks.2.branch2.conv_b.weight |   36864    |
# | blocks.1.multipathway_blocks.0.res_blocks.2.branch2.norm_b.weight |     64     |
# |  blocks.1.multipathway_blocks.0.res_blocks.2.branch2.norm_b.bias  |     64     |
# | blocks.1.multipathway_blocks.0.res_blocks.2.branch2.conv_c.weight |   16384    |
# | blocks.1.multipathway_blocks.0.res_blocks.2.branch2.norm_c.weight |    256     |
# |  blocks.1.multipathway_blocks.0.res_blocks.2.branch2.norm_c.bias  |    256     |
# |  blocks.1.multipathway_blocks.1.res_blocks.0.branch1_conv.weight  |    256     |
# |  blocks.1.multipathway_blocks.1.res_blocks.0.branch1_norm.weight  |     32     |
# |   blocks.1.multipathway_blocks.1.res_blocks.0.branch1_norm.bias   |     32     |
# | blocks.1.multipathway_blocks.1.res_blocks.0.branch2.conv_a.weight |    192     |
# | blocks.1.multipathway_blocks.1.res_blocks.0.branch2.norm_a.weight |     8      |
# |  blocks.1.multipathway_blocks.1.res_blocks.0.branch2.norm_a.bias  |     8      |
# | blocks.1.multipathway_blocks.1.res_blocks.0.branch2.conv_b.weight |    576     |
# | blocks.1.multipathway_blocks.1.res_blocks.0.branch2.norm_b.weight |     8      |
# |  blocks.1.multipathway_blocks.1.res_blocks.0.branch2.norm_b.bias  |     8      |
# | blocks.1.multipathway_blocks.1.res_blocks.0.branch2.conv_c.weight |    256     |
# | blocks.1.multipathway_blocks.1.res_blocks.0.branch2.norm_c.weight |     32     |
# |  blocks.1.multipathway_blocks.1.res_blocks.0.branch2.norm_c.bias  |     32     |
# | blocks.1.multipathway_blocks.1.res_blocks.1.branch2.conv_a.weight |    768     |
# | blocks.1.multipathway_blocks.1.res_blocks.1.branch2.norm_a.weight |     8      |
# |  blocks.1.multipathway_blocks.1.res_blocks.1.branch2.norm_a.bias  |     8      |
# | blocks.1.multipathway_blocks.1.res_blocks.1.branch2.conv_b.weight |    576     |
# | blocks.1.multipathway_blocks.1.res_blocks.1.branch2.norm_b.weight |     8      |
# |  blocks.1.multipathway_blocks.1.res_blocks.1.branch2.norm_b.bias  |     8      |
# | blocks.1.multipathway_blocks.1.res_blocks.1.branch2.conv_c.weight |    256     |
# | blocks.1.multipathway_blocks.1.res_blocks.1.branch2.norm_c.weight |     32     |
# |  blocks.1.multipathway_blocks.1.res_blocks.1.branch2.norm_c.bias  |     32     |
# | blocks.1.multipathway_blocks.1.res_blocks.2.branch2.conv_a.weight |    768     |
# | blocks.1.multipathway_blocks.1.res_blocks.2.branch2.norm_a.weight |     8      |
# |  blocks.1.multipathway_blocks.1.res_blocks.2.branch2.norm_a.bias  |     8      |
# | blocks.1.multipathway_blocks.1.res_blocks.2.branch2.conv_b.weight |    576     |
# | blocks.1.multipathway_blocks.1.res_blocks.2.branch2.norm_b.weight |     8      |
# |  blocks.1.multipathway_blocks.1.res_blocks.2.branch2.norm_b.bias  |     8      |
# | blocks.1.multipathway_blocks.1.res_blocks.2.branch2.conv_c.weight |    256     |
# | blocks.1.multipathway_blocks.1.res_blocks.2.branch2.norm_c.weight |     32     |
# |  blocks.1.multipathway_blocks.1.res_blocks.2.branch2.norm_c.bias  |     32     |
# |       blocks.1.multipathway_fusion.conv_fast_to_slow.weight       |   14336    |
# |              blocks.1.multipathway_fusion.norm.weight             |     64     |
# |               blocks.1.multipathway_fusion.norm.bias              |     64     |
# |  blocks.2.multipathway_blocks.0.res_blocks.0.branch1_conv.weight  |   163840   |
# |  blocks.2.multipathway_blocks.0.res_blocks.0.branch1_norm.weight  |    512     |
# |   blocks.2.multipathway_blocks.0.res_blocks.0.branch1_norm.bias   |    512     |
# | blocks.2.multipathway_blocks.0.res_blocks.0.branch2.conv_a.weight |   40960    |
# | blocks.2.multipathway_blocks.0.res_blocks.0.branch2.norm_a.weight |    128     |
# |  blocks.2.multipathway_blocks.0.res_blocks.0.branch2.norm_a.bias  |    128     |
# | blocks.2.multipathway_blocks.0.res_blocks.0.branch2.conv_b.weight |   147456   |
# | blocks.2.multipathway_blocks.0.res_blocks.0.branch2.norm_b.weight |    128     |
# |  blocks.2.multipathway_blocks.0.res_blocks.0.branch2.norm_b.bias  |    128     |
# | blocks.2.multipathway_blocks.0.res_blocks.0.branch2.conv_c.weight |   65536    |
# | blocks.2.multipathway_blocks.0.res_blocks.0.branch2.norm_c.weight |    512     |
# |  blocks.2.multipathway_blocks.0.res_blocks.0.branch2.norm_c.bias  |    512     |
# | blocks.2.multipathway_blocks.0.res_blocks.1.branch2.conv_a.weight |   65536    |
# | blocks.2.multipathway_blocks.0.res_blocks.1.branch2.norm_a.weight |    128     |
# |  blocks.2.multipathway_blocks.0.res_blocks.1.branch2.norm_a.bias  |    128     |
# | blocks.2.multipathway_blocks.0.res_blocks.1.branch2.conv_b.weight |   147456   |
# | blocks.2.multipathway_blocks.0.res_blocks.1.branch2.norm_b.weight |    128     |
# |  blocks.2.multipathway_blocks.0.res_blocks.1.branch2.norm_b.bias  |    128     |
# | blocks.2.multipathway_blocks.0.res_blocks.1.branch2.conv_c.weight |   65536    |
# | blocks.2.multipathway_blocks.0.res_blocks.1.branch2.norm_c.weight |    512     |
# |  blocks.2.multipathway_blocks.0.res_blocks.1.branch2.norm_c.bias  |    512     |
# | blocks.2.multipathway_blocks.0.res_blocks.2.branch2.conv_a.weight |   65536    |
# | blocks.2.multipathway_blocks.0.res_blocks.2.branch2.norm_a.weight |    128     |
# |  blocks.2.multipathway_blocks.0.res_blocks.2.branch2.norm_a.bias  |    128     |
# | blocks.2.multipathway_blocks.0.res_blocks.2.branch2.conv_b.weight |   147456   |
# | blocks.2.multipathway_blocks.0.res_blocks.2.branch2.norm_b.weight |    128     |
# |  blocks.2.multipathway_blocks.0.res_blocks.2.branch2.norm_b.bias  |    128     |
# | blocks.2.multipathway_blocks.0.res_blocks.2.branch2.conv_c.weight |   65536    |
# | blocks.2.multipathway_blocks.0.res_blocks.2.branch2.norm_c.weight |    512     |
# |  blocks.2.multipathway_blocks.0.res_blocks.2.branch2.norm_c.bias  |    512     |
# | blocks.2.multipathway_blocks.0.res_blocks.3.branch2.conv_a.weight |   65536    |
# | blocks.2.multipathway_blocks.0.res_blocks.3.branch2.norm_a.weight |    128     |
# |  blocks.2.multipathway_blocks.0.res_blocks.3.branch2.norm_a.bias  |    128     |
# | blocks.2.multipathway_blocks.0.res_blocks.3.branch2.conv_b.weight |   147456   |
# | blocks.2.multipathway_blocks.0.res_blocks.3.branch2.norm_b.weight |    128     |
# |  blocks.2.multipathway_blocks.0.res_blocks.3.branch2.norm_b.bias  |    128     |
# | blocks.2.multipathway_blocks.0.res_blocks.3.branch2.conv_c.weight |   65536    |
# | blocks.2.multipathway_blocks.0.res_blocks.3.branch2.norm_c.weight |    512     |
# |  blocks.2.multipathway_blocks.0.res_blocks.3.branch2.norm_c.bias  |    512     |
# |  blocks.2.multipathway_blocks.1.res_blocks.0.branch1_conv.weight  |    2048    |
# |  blocks.2.multipathway_blocks.1.res_blocks.0.branch1_norm.weight  |     64     |
# |   blocks.2.multipathway_blocks.1.res_blocks.0.branch1_norm.bias   |     64     |
# | blocks.2.multipathway_blocks.1.res_blocks.0.branch2.conv_a.weight |    1536    |
# | blocks.2.multipathway_blocks.1.res_blocks.0.branch2.norm_a.weight |     16     |
# |  blocks.2.multipathway_blocks.1.res_blocks.0.branch2.norm_a.bias  |     16     |
# | blocks.2.multipathway_blocks.1.res_blocks.0.branch2.conv_b.weight |    2304    |
# | blocks.2.multipathway_blocks.1.res_blocks.0.branch2.norm_b.weight |     16     |
# |  blocks.2.multipathway_blocks.1.res_blocks.0.branch2.norm_b.bias  |     16     |
# | blocks.2.multipathway_blocks.1.res_blocks.0.branch2.conv_c.weight |    1024    |
# | blocks.2.multipathway_blocks.1.res_blocks.0.branch2.norm_c.weight |     64     |
# |  blocks.2.multipathway_blocks.1.res_blocks.0.branch2.norm_c.bias  |     64     |
# | blocks.2.multipathway_blocks.1.res_blocks.1.branch2.conv_a.weight |    3072    |
# | blocks.2.multipathway_blocks.1.res_blocks.1.branch2.norm_a.weight |     16     |
# |  blocks.2.multipathway_blocks.1.res_blocks.1.branch2.norm_a.bias  |     16     |
# | blocks.2.multipathway_blocks.1.res_blocks.1.branch2.conv_b.weight |    2304    |
# | blocks.2.multipathway_blocks.1.res_blocks.1.branch2.norm_b.weight |     16     |
# |  blocks.2.multipathway_blocks.1.res_blocks.1.branch2.norm_b.bias  |     16     |
# | blocks.2.multipathway_blocks.1.res_blocks.1.branch2.conv_c.weight |    1024    |
# | blocks.2.multipathway_blocks.1.res_blocks.1.branch2.norm_c.weight |     64     |
# |  blocks.2.multipathway_blocks.1.res_blocks.1.branch2.norm_c.bias  |     64     |
# | blocks.2.multipathway_blocks.1.res_blocks.2.branch2.conv_a.weight |    3072    |
# | blocks.2.multipathway_blocks.1.res_blocks.2.branch2.norm_a.weight |     16     |
# |  blocks.2.multipathway_blocks.1.res_blocks.2.branch2.norm_a.bias  |     16     |
# | blocks.2.multipathway_blocks.1.res_blocks.2.branch2.conv_b.weight |    2304    |
# | blocks.2.multipathway_blocks.1.res_blocks.2.branch2.norm_b.weight |     16     |
# |  blocks.2.multipathway_blocks.1.res_blocks.2.branch2.norm_b.bias  |     16     |
# | blocks.2.multipathway_blocks.1.res_blocks.2.branch2.conv_c.weight |    1024    |
# | blocks.2.multipathway_blocks.1.res_blocks.2.branch2.norm_c.weight |     64     |
# |  blocks.2.multipathway_blocks.1.res_blocks.2.branch2.norm_c.bias  |     64     |
# | blocks.2.multipathway_blocks.1.res_blocks.3.branch2.conv_a.weight |    3072    |
# | blocks.2.multipathway_blocks.1.res_blocks.3.branch2.norm_a.weight |     16     |
# |  blocks.2.multipathway_blocks.1.res_blocks.3.branch2.norm_a.bias  |     16     |
# | blocks.2.multipathway_blocks.1.res_blocks.3.branch2.conv_b.weight |    2304    |
# | blocks.2.multipathway_blocks.1.res_blocks.3.branch2.norm_b.weight |     16     |
# |  blocks.2.multipathway_blocks.1.res_blocks.3.branch2.norm_b.bias  |     16     |
# | blocks.2.multipathway_blocks.1.res_blocks.3.branch2.conv_c.weight |    1024    |
# | blocks.2.multipathway_blocks.1.res_blocks.3.branch2.norm_c.weight |     64     |
# |  blocks.2.multipathway_blocks.1.res_blocks.3.branch2.norm_c.bias  |     64     |
# |       blocks.2.multipathway_fusion.conv_fast_to_slow.weight       |   57344    |
# |              blocks.2.multipathway_fusion.norm.weight             |    128     |
# |               blocks.2.multipathway_fusion.norm.bias              |    128     |
# |  blocks.3.multipathway_blocks.0.res_blocks.0.branch1_conv.weight  |   655360   |
# |  blocks.3.multipathway_blocks.0.res_blocks.0.branch1_norm.weight  |    1024    |
# |   blocks.3.multipathway_blocks.0.res_blocks.0.branch1_norm.bias   |    1024    |
# | blocks.3.multipathway_blocks.0.res_blocks.0.branch2.conv_a.weight |   491520   |
# | blocks.3.multipathway_blocks.0.res_blocks.0.branch2.norm_a.weight |    256     |
# |  blocks.3.multipathway_blocks.0.res_blocks.0.branch2.norm_a.bias  |    256     |
# | blocks.3.multipathway_blocks.0.res_blocks.0.branch2.conv_b.weight |   589824   |
# | blocks.3.multipathway_blocks.0.res_blocks.0.branch2.norm_b.weight |    256     |
# |  blocks.3.multipathway_blocks.0.res_blocks.0.branch2.norm_b.bias  |    256     |
# | blocks.3.multipathway_blocks.0.res_blocks.0.branch2.conv_c.weight |   262144   |
# | blocks.3.multipathway_blocks.0.res_blocks.0.branch2.norm_c.weight |    1024    |
# |  blocks.3.multipathway_blocks.0.res_blocks.0.branch2.norm_c.bias  |    1024    |
# | blocks.3.multipathway_blocks.0.res_blocks.1.branch2.conv_a.weight |   786432   |
# | blocks.3.multipathway_blocks.0.res_blocks.1.branch2.norm_a.weight |    256     |
# |  blocks.3.multipathway_blocks.0.res_blocks.1.branch2.norm_a.bias  |    256     |
# | blocks.3.multipathway_blocks.0.res_blocks.1.branch2.conv_b.weight |   589824   |
# | blocks.3.multipathway_blocks.0.res_blocks.1.branch2.norm_b.weight |    256     |
# |  blocks.3.multipathway_blocks.0.res_blocks.1.branch2.norm_b.bias  |    256     |
# | blocks.3.multipathway_blocks.0.res_blocks.1.branch2.conv_c.weight |   262144   |
# | blocks.3.multipathway_blocks.0.res_blocks.1.branch2.norm_c.weight |    1024    |
# |  blocks.3.multipathway_blocks.0.res_blocks.1.branch2.norm_c.bias  |    1024    |
# | blocks.3.multipathway_blocks.0.res_blocks.2.branch2.conv_a.weight |   786432   |
# | blocks.3.multipathway_blocks.0.res_blocks.2.branch2.norm_a.weight |    256     |
# |  blocks.3.multipathway_blocks.0.res_blocks.2.branch2.norm_a.bias  |    256     |
# | blocks.3.multipathway_blocks.0.res_blocks.2.branch2.conv_b.weight |   589824   |
# | blocks.3.multipathway_blocks.0.res_blocks.2.branch2.norm_b.weight |    256     |
# |  blocks.3.multipathway_blocks.0.res_blocks.2.branch2.norm_b.bias  |    256     |
# | blocks.3.multipathway_blocks.0.res_blocks.2.branch2.conv_c.weight |   262144   |
# | blocks.3.multipathway_blocks.0.res_blocks.2.branch2.norm_c.weight |    1024    |
# |  blocks.3.multipathway_blocks.0.res_blocks.2.branch2.norm_c.bias  |    1024    |
# | blocks.3.multipathway_blocks.0.res_blocks.3.branch2.conv_a.weight |   786432   |
# | blocks.3.multipathway_blocks.0.res_blocks.3.branch2.norm_a.weight |    256     |
# |  blocks.3.multipathway_blocks.0.res_blocks.3.branch2.norm_a.bias  |    256     |
# | blocks.3.multipathway_blocks.0.res_blocks.3.branch2.conv_b.weight |   589824   |
# | blocks.3.multipathway_blocks.0.res_blocks.3.branch2.norm_b.weight |    256     |
# |  blocks.3.multipathway_blocks.0.res_blocks.3.branch2.norm_b.bias  |    256     |
# | blocks.3.multipathway_blocks.0.res_blocks.3.branch2.conv_c.weight |   262144   |
# | blocks.3.multipathway_blocks.0.res_blocks.3.branch2.norm_c.weight |    1024    |
# |  blocks.3.multipathway_blocks.0.res_blocks.3.branch2.norm_c.bias  |    1024    |
# | blocks.3.multipathway_blocks.0.res_blocks.4.branch2.conv_a.weight |   786432   |
# | blocks.3.multipathway_blocks.0.res_blocks.4.branch2.norm_a.weight |    256     |
# |  blocks.3.multipathway_blocks.0.res_blocks.4.branch2.norm_a.bias  |    256     |
# | blocks.3.multipathway_blocks.0.res_blocks.4.branch2.conv_b.weight |   589824   |
# | blocks.3.multipathway_blocks.0.res_blocks.4.branch2.norm_b.weight |    256     |
# |  blocks.3.multipathway_blocks.0.res_blocks.4.branch2.norm_b.bias  |    256     |
# | blocks.3.multipathway_blocks.0.res_blocks.4.branch2.conv_c.weight |   262144   |
# | blocks.3.multipathway_blocks.0.res_blocks.4.branch2.norm_c.weight |    1024    |
# |  blocks.3.multipathway_blocks.0.res_blocks.4.branch2.norm_c.bias  |    1024    |
# | blocks.3.multipathway_blocks.0.res_blocks.5.branch2.conv_a.weight |   786432   |
# | blocks.3.multipathway_blocks.0.res_blocks.5.branch2.norm_a.weight |    256     |
# |  blocks.3.multipathway_blocks.0.res_blocks.5.branch2.norm_a.bias  |    256     |
# | blocks.3.multipathway_blocks.0.res_blocks.5.branch2.conv_b.weight |   589824   |
# | blocks.3.multipathway_blocks.0.res_blocks.5.branch2.norm_b.weight |    256     |
# |  blocks.3.multipathway_blocks.0.res_blocks.5.branch2.norm_b.bias  |    256     |
# | blocks.3.multipathway_blocks.0.res_blocks.5.branch2.conv_c.weight |   262144   |
# | blocks.3.multipathway_blocks.0.res_blocks.5.branch2.norm_c.weight |    1024    |
# |  blocks.3.multipathway_blocks.0.res_blocks.5.branch2.norm_c.bias  |    1024    |
# |  blocks.3.multipathway_blocks.1.res_blocks.0.branch1_conv.weight  |    8192    |
# |  blocks.3.multipathway_blocks.1.res_blocks.0.branch1_norm.weight  |    128     |
# |   blocks.3.multipathway_blocks.1.res_blocks.0.branch1_norm.bias   |    128     |
# | blocks.3.multipathway_blocks.1.res_blocks.0.branch2.conv_a.weight |    6144    |
# | blocks.3.multipathway_blocks.1.res_blocks.0.branch2.norm_a.weight |     32     |
# |  blocks.3.multipathway_blocks.1.res_blocks.0.branch2.norm_a.bias  |     32     |
# | blocks.3.multipathway_blocks.1.res_blocks.0.branch2.conv_b.weight |    9216    |
# | blocks.3.multipathway_blocks.1.res_blocks.0.branch2.norm_b.weight |     32     |
# |  blocks.3.multipathway_blocks.1.res_blocks.0.branch2.norm_b.bias  |     32     |
# | blocks.3.multipathway_blocks.1.res_blocks.0.branch2.conv_c.weight |    4096    |
# | blocks.3.multipathway_blocks.1.res_blocks.0.branch2.norm_c.weight |    128     |
# |  blocks.3.multipathway_blocks.1.res_blocks.0.branch2.norm_c.bias  |    128     |
# | blocks.3.multipathway_blocks.1.res_blocks.1.branch2.conv_a.weight |   12288    |
# | blocks.3.multipathway_blocks.1.res_blocks.1.branch2.norm_a.weight |     32     |
# |  blocks.3.multipathway_blocks.1.res_blocks.1.branch2.norm_a.bias  |     32     |
# | blocks.3.multipathway_blocks.1.res_blocks.1.branch2.conv_b.weight |    9216    |
# | blocks.3.multipathway_blocks.1.res_blocks.1.branch2.norm_b.weight |     32     |
# |  blocks.3.multipathway_blocks.1.res_blocks.1.branch2.norm_b.bias  |     32     |
# | blocks.3.multipathway_blocks.1.res_blocks.1.branch2.conv_c.weight |    4096    |
# | blocks.3.multipathway_blocks.1.res_blocks.1.branch2.norm_c.weight |    128     |
# |  blocks.3.multipathway_blocks.1.res_blocks.1.branch2.norm_c.bias  |    128     |
# | blocks.3.multipathway_blocks.1.res_blocks.2.branch2.conv_a.weight |   12288    |
# | blocks.3.multipathway_blocks.1.res_blocks.2.branch2.norm_a.weight |     32     |
# |  blocks.3.multipathway_blocks.1.res_blocks.2.branch2.norm_a.bias  |     32     |
# | blocks.3.multipathway_blocks.1.res_blocks.2.branch2.conv_b.weight |    9216    |
# | blocks.3.multipathway_blocks.1.res_blocks.2.branch2.norm_b.weight |     32     |
# |  blocks.3.multipathway_blocks.1.res_blocks.2.branch2.norm_b.bias  |     32     |
# | blocks.3.multipathway_blocks.1.res_blocks.2.branch2.conv_c.weight |    4096    |
# | blocks.3.multipathway_blocks.1.res_blocks.2.branch2.norm_c.weight |    128     |
# |  blocks.3.multipathway_blocks.1.res_blocks.2.branch2.norm_c.bias  |    128     |
# | blocks.3.multipathway_blocks.1.res_blocks.3.branch2.conv_a.weight |   12288    |
# | blocks.3.multipathway_blocks.1.res_blocks.3.branch2.norm_a.weight |     32     |
# |  blocks.3.multipathway_blocks.1.res_blocks.3.branch2.norm_a.bias  |     32     |
# | blocks.3.multipathway_blocks.1.res_blocks.3.branch2.conv_b.weight |    9216    |
# | blocks.3.multipathway_blocks.1.res_blocks.3.branch2.norm_b.weight |     32     |
# |  blocks.3.multipathway_blocks.1.res_blocks.3.branch2.norm_b.bias  |     32     |
# | blocks.3.multipathway_blocks.1.res_blocks.3.branch2.conv_c.weight |    4096    |
# | blocks.3.multipathway_blocks.1.res_blocks.3.branch2.norm_c.weight |    128     |
# |  blocks.3.multipathway_blocks.1.res_blocks.3.branch2.norm_c.bias  |    128     |
# | blocks.3.multipathway_blocks.1.res_blocks.4.branch2.conv_a.weight |   12288    |
# | blocks.3.multipathway_blocks.1.res_blocks.4.branch2.norm_a.weight |     32     |
# |  blocks.3.multipathway_blocks.1.res_blocks.4.branch2.norm_a.bias  |     32     |
# | blocks.3.multipathway_blocks.1.res_blocks.4.branch2.conv_b.weight |    9216    |
# | blocks.3.multipathway_blocks.1.res_blocks.4.branch2.norm_b.weight |     32     |
# |  blocks.3.multipathway_blocks.1.res_blocks.4.branch2.norm_b.bias  |     32     |
# | blocks.3.multipathway_blocks.1.res_blocks.4.branch2.conv_c.weight |    4096    |
# | blocks.3.multipathway_blocks.1.res_blocks.4.branch2.norm_c.weight |    128     |
# |  blocks.3.multipathway_blocks.1.res_blocks.4.branch2.norm_c.bias  |    128     |
# | blocks.3.multipathway_blocks.1.res_blocks.5.branch2.conv_a.weight |   12288    |
# | blocks.3.multipathway_blocks.1.res_blocks.5.branch2.norm_a.weight |     32     |
# |  blocks.3.multipathway_blocks.1.res_blocks.5.branch2.norm_a.bias  |     32     |
# | blocks.3.multipathway_blocks.1.res_blocks.5.branch2.conv_b.weight |    9216    |
# | blocks.3.multipathway_blocks.1.res_blocks.5.branch2.norm_b.weight |     32     |
# |  blocks.3.multipathway_blocks.1.res_blocks.5.branch2.norm_b.bias  |     32     |
# | blocks.3.multipathway_blocks.1.res_blocks.5.branch2.conv_c.weight |    4096    |
# | blocks.3.multipathway_blocks.1.res_blocks.5.branch2.norm_c.weight |    128     |
# |  blocks.3.multipathway_blocks.1.res_blocks.5.branch2.norm_c.bias  |    128     |
# |       blocks.3.multipathway_fusion.conv_fast_to_slow.weight       |   229376   |
# |              blocks.3.multipathway_fusion.norm.weight             |    256     |
# |               blocks.3.multipathway_fusion.norm.bias              |    256     |
# |  blocks.4.multipathway_blocks.0.res_blocks.0.branch1_conv.weight  |  2621440   |
# |  blocks.4.multipathway_blocks.0.res_blocks.0.branch1_norm.weight  |    2048    |
# |   blocks.4.multipathway_blocks.0.res_blocks.0.branch1_norm.bias   |    2048    |
# | blocks.4.multipathway_blocks.0.res_blocks.0.branch2.conv_a.weight |  1966080   |
# | blocks.4.multipathway_blocks.0.res_blocks.0.branch2.norm_a.weight |    512     |
# |  blocks.4.multipathway_blocks.0.res_blocks.0.branch2.norm_a.bias  |    512     |
# | blocks.4.multipathway_blocks.0.res_blocks.0.branch2.conv_b.weight |  2359296   |
# | blocks.4.multipathway_blocks.0.res_blocks.0.branch2.norm_b.weight |    512     |
# |  blocks.4.multipathway_blocks.0.res_blocks.0.branch2.norm_b.bias  |    512     |
# | blocks.4.multipathway_blocks.0.res_blocks.0.branch2.conv_c.weight |  1048576   |
# | blocks.4.multipathway_blocks.0.res_blocks.0.branch2.norm_c.weight |    2048    |
# |  blocks.4.multipathway_blocks.0.res_blocks.0.branch2.norm_c.bias  |    2048    |
# | blocks.4.multipathway_blocks.0.res_blocks.1.branch2.conv_a.weight |  3145728   |
# | blocks.4.multipathway_blocks.0.res_blocks.1.branch2.norm_a.weight |    512     |
# |  blocks.4.multipathway_blocks.0.res_blocks.1.branch2.norm_a.bias  |    512     |
# | blocks.4.multipathway_blocks.0.res_blocks.1.branch2.conv_b.weight |  2359296   |
# | blocks.4.multipathway_blocks.0.res_blocks.1.branch2.norm_b.weight |    512     |
# |  blocks.4.multipathway_blocks.0.res_blocks.1.branch2.norm_b.bias  |    512     |
# | blocks.4.multipathway_blocks.0.res_blocks.1.branch2.conv_c.weight |  1048576   |
# | blocks.4.multipathway_blocks.0.res_blocks.1.branch2.norm_c.weight |    2048    |
# |  blocks.4.multipathway_blocks.0.res_blocks.1.branch2.norm_c.bias  |    2048    |
# | blocks.4.multipathway_blocks.0.res_blocks.2.branch2.conv_a.weight |  3145728   |
# | blocks.4.multipathway_blocks.0.res_blocks.2.branch2.norm_a.weight |    512     |
# |  blocks.4.multipathway_blocks.0.res_blocks.2.branch2.norm_a.bias  |    512     |
# | blocks.4.multipathway_blocks.0.res_blocks.2.branch2.conv_b.weight |  2359296   |
# | blocks.4.multipathway_blocks.0.res_blocks.2.branch2.norm_b.weight |    512     |
# |  blocks.4.multipathway_blocks.0.res_blocks.2.branch2.norm_b.bias  |    512     |
# | blocks.4.multipathway_blocks.0.res_blocks.2.branch2.conv_c.weight |  1048576   |
# | blocks.4.multipathway_blocks.0.res_blocks.2.branch2.norm_c.weight |    2048    |
# |  blocks.4.multipathway_blocks.0.res_blocks.2.branch2.norm_c.bias  |    2048    |
# |  blocks.4.multipathway_blocks.1.res_blocks.0.branch1_conv.weight  |   32768    |
# |  blocks.4.multipathway_blocks.1.res_blocks.0.branch1_norm.weight  |    256     |
# |   blocks.4.multipathway_blocks.1.res_blocks.0.branch1_norm.bias   |    256     |
# | blocks.4.multipathway_blocks.1.res_blocks.0.branch2.conv_a.weight |   24576    |
# | blocks.4.multipathway_blocks.1.res_blocks.0.branch2.norm_a.weight |     64     |
# |  blocks.4.multipathway_blocks.1.res_blocks.0.branch2.norm_a.bias  |     64     |
# | blocks.4.multipathway_blocks.1.res_blocks.0.branch2.conv_b.weight |   36864    |
# | blocks.4.multipathway_blocks.1.res_blocks.0.branch2.norm_b.weight |     64     |
# |  blocks.4.multipathway_blocks.1.res_blocks.0.branch2.norm_b.bias  |     64     |
# | blocks.4.multipathway_blocks.1.res_blocks.0.branch2.conv_c.weight |   16384    |
# | blocks.4.multipathway_blocks.1.res_blocks.0.branch2.norm_c.weight |    256     |
# |  blocks.4.multipathway_blocks.1.res_blocks.0.branch2.norm_c.bias  |    256     |
# | blocks.4.multipathway_blocks.1.res_blocks.1.branch2.conv_a.weight |   49152    |
# | blocks.4.multipathway_blocks.1.res_blocks.1.branch2.norm_a.weight |     64     |
# |  blocks.4.multipathway_blocks.1.res_blocks.1.branch2.norm_a.bias  |     64     |
# | blocks.4.multipathway_blocks.1.res_blocks.1.branch2.conv_b.weight |   36864    |
# | blocks.4.multipathway_blocks.1.res_blocks.1.branch2.norm_b.weight |     64     |
# |  blocks.4.multipathway_blocks.1.res_blocks.1.branch2.norm_b.bias  |     64     |
# | blocks.4.multipathway_blocks.1.res_blocks.1.branch2.conv_c.weight |   16384    |
# | blocks.4.multipathway_blocks.1.res_blocks.1.branch2.norm_c.weight |    256     |
# |  blocks.4.multipathway_blocks.1.res_blocks.1.branch2.norm_c.bias  |    256     |
# | blocks.4.multipathway_blocks.1.res_blocks.2.branch2.conv_a.weight |   49152    |
# | blocks.4.multipathway_blocks.1.res_blocks.2.branch2.norm_a.weight |     64     |
# |  blocks.4.multipathway_blocks.1.res_blocks.2.branch2.norm_a.bias  |     64     |
# | blocks.4.multipathway_blocks.1.res_blocks.2.branch2.conv_b.weight |   36864    |
# | blocks.4.multipathway_blocks.1.res_blocks.2.branch2.norm_b.weight |     64     |
# |  blocks.4.multipathway_blocks.1.res_blocks.2.branch2.norm_b.bias  |     64     |
# | blocks.4.multipathway_blocks.1.res_blocks.2.branch2.conv_c.weight |   16384    |
# | blocks.4.multipathway_blocks.1.res_blocks.2.branch2.norm_c.weight |    256     |
# |  blocks.4.multipathway_blocks.1.res_blocks.2.branch2.norm_c.bias  |    256     |
# |                        blocks.6.proj.weight                       |   921600   |
# |                         blocks.6.proj.bias                        |    400     |
# +-------------------------------------------------------------------+------------+
# Total Trainable Params: 34566488
# 34566488

# %% [markdown]
# Import remaining functions:

# %%
# !pip install av
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting av
#   Downloading av-10.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 17.4 MB/s eta 0:00:00
# Installing collected packages: av
# Successfully installed av-10.0.0

# %%
from typing import Dict
import json
import urllib
from torchvision.transforms import Compose, Lambda
from torchvision.transforms._transforms_video import (
    CenterCropVideo,
    NormalizeVideo,
)
from pytorchvideo.data.encoded_video import EncodedVideo
from pytorchvideo.transforms import (
    ApplyTransformToKey,
    ShortSideScale,
    UniformTemporalSubsample,
    UniformCropVideo
)
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/transforms/_functional_video.py:6: UserWarning: The 'torchvision.transforms._functional_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms.functional' module instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/transforms/_transforms_video.py:22: UserWarning: The 'torchvision.transforms._transforms_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms' module instead.
#   warnings.warn(

# %% [markdown]
# #### Setup
#
# Set the model to eval mode and move to desired device.

# %%
# Set to GPU or CPU
device = "cpu"
model = model.eval()
model = model.to(device)

# %% [markdown]
# Download the id to label mapping for the Kinetics 400 dataset on which the torch hub models were trained. This will be used to get the category label names from the predicted class ids.

# %%
json_url = "https://dl.fbaipublicfiles.com/pyslowfast/dataset/class_names/kinetics_classnames.json"
json_filename = "kinetics_classnames.json"
try: urllib.URLopener().retrieve(json_url, json_filename)
except: urllib.request.urlretrieve(json_url, json_filename)

# %%
with open(json_filename, "r") as f:
    kinetics_classnames = json.load(f)

# Create an id to label name mapping
kinetics_id_to_classname = {}
for k, v in kinetics_classnames.items():
    kinetics_id_to_classname[v] = str(k).replace('"', "")

# %% [markdown]
# #### Define input transform

# %%
side_size = 256
mean = [0.45, 0.45, 0.45]
std = [0.225, 0.225, 0.225]
crop_size = 256
num_frames = 32
sampling_rate = 2
frames_per_second = 30
slowfast_alpha = 4
num_clips = 10
num_crops = 3

class PackPathway(torch.nn.Module):
    """
    Transform for converting video frames as a list of tensors. 
    """
    def __init__(self):
        super().__init__()
        
    def forward(self, frames: torch.Tensor):
        fast_pathway = frames
        # Perform temporal sampling from the fast pathway.
        slow_pathway = torch.index_select(
            frames,
            1,
            torch.linspace(
                0, frames.shape[1] - 1, frames.shape[1] // slowfast_alpha
            ).long(),
        )
        frame_list = [slow_pathway, fast_pathway]
        return frame_list

transform =  ApplyTransformToKey(
    key="video",
    transform=Compose(
        [
            UniformTemporalSubsample(num_frames),
            Lambda(lambda x: x/255.0),
            NormalizeVideo(mean, std),
            ShortSideScale(
                size=side_size
            ),
            CenterCropVideo(crop_size),
            PackPathway()
        ]
    ),
)

# The duration of the input clip is also specific to the model.
clip_duration = (num_frames * sampling_rate)/frames_per_second

# %% [markdown]
# #### Run Inference
#
# Download an example video.

# %%
url_link = "https://dl.fbaipublicfiles.com/pytorchvideo/projects/archery.mp4"
video_path = 'archery.mp4'
try: urllib.URLopener().retrieve(url_link, video_path)
except: urllib.request.urlretrieve(url_link, video_path)

# %% [markdown]
# Load the video and transform it to the input format required by the model.

# %%
# Select the duration of the clip to load by specifying the start and end duration
# The start_sec should correspond to where the action occurs in the video
start_sec = 0
end_sec = start_sec + clip_duration

# Initialize an EncodedVideo helper class and load the video
video = EncodedVideo.from_path(video_path)

# Load the desired clip
video_data = video.get_clip(start_sec=start_sec, end_sec=end_sec)

# Apply a transform to normalize the video input
video_data = transform(video_data)

# Move the inputs to the desired device
inputs = video_data["video"]
inputs = [i.to(device)[None, ...] for i in inputs]

# %% [markdown]
# #### Get Predictions

# %%
# Pass the input clip through the model
preds = model(inputs)

# Get the predicted classes
post_act = torch.nn.Softmax(dim=1)
preds = post_act(preds)
pred_classes = preds.topk(k=5).indices[0]

# Map the predicted classes to the label names
pred_class_names = [kinetics_id_to_classname[int(i)] for i in pred_classes]
print("Top 5 predicted labels: %s" % ", ".join(pred_class_names))
# Out:
# Top 5 predicted labels: archery, throwing axe, playing paintball, disc golfing, riding or walking with horse

# %% [markdown]
# ### Model Description
# SlowFast model architectures are based on [1] with pretrained weights using the 8x8 setting
# on the Kinetics dataset.
#
# | arch | depth | frame length x sample rate | top 1 | top 5 | Flops (G) | Params (M) |
# | --------------- | ----------- | ----------- | ----------- | ----------- | ----------- |  ----------- | ----------- |
# | SlowFast | R50   | 8x8                        | 76.94 | 92.69 | 65.71     | 34.57      |
# | SlowFast | R101  | 8x8                        | 77.90 | 93.27 | 127.20    | 62.83      |
#
#
# ### References
# [1] Christoph Feichtenhofer et al, "SlowFast Networks for Video Recognition"
# https://arxiv.org/pdf/1812.03982.pdf

# %% [markdown]
# ### check count_parameters

# %%
# pip install prettytable
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: prettytable in /usr/local/lib/python3.8/dist-packages (3.6.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prettytable) (0.2.5)

# %%
count_parameters(model)
# Out:
# +-------------------------------------------------------------------+------------+
# |                              Modules                              | Parameters |
# +-------------------------------------------------------------------+------------+
# |             blocks.0.multipathway_blocks.0.conv.weight            |    9408    |
# |             blocks.0.multipathway_blocks.0.norm.weight            |     64     |
# |              blocks.0.multipathway_blocks.0.norm.bias             |     64     |
# |             blocks.0.multipathway_blocks.1.conv.weight            |    5880    |
# |             blocks.0.multipathway_blocks.1.norm.weight            |     8      |
# |              blocks.0.multipathway_blocks.1.norm.bias             |     8      |
# |       blocks.0.multipathway_fusion.conv_fast_to_slow.weight       |    896     |
# |              blocks.0.multipathway_fusion.norm.weight             |     16     |
# |               blocks.0.multipathway_fusion.norm.bias              |     16     |
# |  blocks.1.multipathway_blocks.0.res_blocks.0.branch1_conv.weight  |   20480    |
# |  blocks.1.multipathway_blocks.0.res_blocks.0.branch1_norm.weight  |    256     |
# |   blocks.1.multipathway_blocks.0.res_blocks.0.branch1_norm.bias   |    256     |
# | blocks.1.multipathway_blocks.0.res_blocks.0.branch2.conv_a.weight |    5120    |
# | blocks.1.multipathway_blocks.0.res_blocks.0.branch2.norm_a.weight |     64     |
# |  blocks.1.multipathway_blocks.0.res_blocks.0.branch2.norm_a.bias  |     64     |
# | blocks.1.multipathway_blocks.0.res_blocks.0.branch2.conv_b.weight |   36864    |
# | blocks.1.multipathway_blocks.0.res_blocks.0.branch2.norm_b.weight |     64     |
# |  blocks.1.multipathway_blocks.0.res_blocks.0.branch2.norm_b.bias  |     64     |
# | blocks.1.multipathway_blocks.0.res_blocks.0.branch2.conv_c.weight |   16384    |
# | blocks.1.multipathway_blocks.0.res_blocks.0.branch2.norm_c.weight |    256     |
# |  blocks.1.multipathway_blocks.0.res_blocks.0.branch2.norm_c.bias  |    256     |
# | blocks.1.multipathway_blocks.0.res_blocks.1.branch2.conv_a.weight |   16384    |
# | blocks.1.multipathway_blocks.0.res_blocks.1.branch2.norm_a.weight |     64     |
# |  blocks.1.multipathway_blocks.0.res_blocks.1.branch2.norm_a.bias  |     64     |
# | blocks.1.multipathway_blocks.0.res_blocks.1.branch2.conv_b.weight |   36864    |
# | blocks.1.multipathway_blocks.0.res_blocks.1.branch2.norm_b.weight |     64     |
# |  blocks.1.multipathway_blocks.0.res_blocks.1.branch2.norm_b.bias  |     64     |
# | blocks.1.multipathway_blocks.0.res_blocks.1.branch2.conv_c.weight |   16384    |
# | blocks.1.multipathway_blocks.0.res_blocks.1.branch2.norm_c.weight |    256     |
# |  blocks.1.multipathway_blocks.0.res_blocks.1.branch2.norm_c.bias  |    256     |
# | blocks.1.multipathway_blocks.0.res_blocks.2.branch2.conv_a.weight |   16384    |
# | blocks.1.multipathway_blocks.0.res_blocks.2.branch2.norm_a.weight |     64     |
# |  blocks.1.multipathway_blocks.0.res_blocks.2.branch2.norm_a.bias  |     64     |
# | blocks.1.multipathway_blocks.0.res_blocks.2.branch2.conv_b.weight |   36864    |
# | blocks.1.multipathway_blocks.0.res_blocks.2.branch2.norm_b.weight |     64     |
# |  blocks.1.multipathway_blocks.0.res_blocks.2.branch2.norm_b.bias  |     64     |
# | blocks.1.multipathway_blocks.0.res_blocks.2.branch2.conv_c.weight |   16384    |
# | blocks.1.multipathway_blocks.0.res_blocks.2.branch2.norm_c.weight |    256     |
# |  blocks.1.multipathway_blocks.0.res_blocks.2.branch2.norm_c.bias  |    256     |
# |  blocks.1.multipathway_blocks.1.res_blocks.0.branch1_conv.weight  |    256     |
# |  blocks.1.multipathway_blocks.1.res_blocks.0.branch1_norm.weight  |     32     |
# |   blocks.1.multipathway_blocks.1.res_blocks.0.branch1_norm.bias   |     32     |
# | blocks.1.multipathway_blocks.1.res_blocks.0.branch2.conv_a.weight |    192     |
# | blocks.1.multipathway_blocks.1.res_blocks.0.branch2.norm_a.weight |     8      |
# |  blocks.1.multipathway_blocks.1.res_blocks.0.branch2.norm_a.bias  |     8      |
# | blocks.1.multipathway_blocks.1.res_blocks.0.branch2.conv_b.weight |    576     |
# | blocks.1.multipathway_blocks.1.res_blocks.0.branch2.norm_b.weight |     8      |
# |  blocks.1.multipathway_blocks.1.res_blocks.0.branch2.norm_b.bias  |     8      |
# | blocks.1.multipathway_blocks.1.res_blocks.0.branch2.conv_c.weight |    256     |
# | blocks.1.multipathway_blocks.1.res_blocks.0.branch2.norm_c.weight |     32     |
# |  blocks.1.multipathway_blocks.1.res_blocks.0.branch2.norm_c.bias  |     32     |
# | blocks.1.multipathway_blocks.1.res_blocks.1.branch2.conv_a.weight |    768     |
# | blocks.1.multipathway_blocks.1.res_blocks.1.branch2.norm_a.weight |     8      |
# |  blocks.1.multipathway_blocks.1.res_blocks.1.branch2.norm_a.bias  |     8      |
# | blocks.1.multipathway_blocks.1.res_blocks.1.branch2.conv_b.weight |    576     |
# | blocks.1.multipathway_blocks.1.res_blocks.1.branch2.norm_b.weight |     8      |
# |  blocks.1.multipathway_blocks.1.res_blocks.1.branch2.norm_b.bias  |     8      |
# | blocks.1.multipathway_blocks.1.res_blocks.1.branch2.conv_c.weight |    256     |
# | blocks.1.multipathway_blocks.1.res_blocks.1.branch2.norm_c.weight |     32     |
# |  blocks.1.multipathway_blocks.1.res_blocks.1.branch2.norm_c.bias  |     32     |
# | blocks.1.multipathway_blocks.1.res_blocks.2.branch2.conv_a.weight |    768     |
# | blocks.1.multipathway_blocks.1.res_blocks.2.branch2.norm_a.weight |     8      |
# |  blocks.1.multipathway_blocks.1.res_blocks.2.branch2.norm_a.bias  |     8      |
# | blocks.1.multipathway_blocks.1.res_blocks.2.branch2.conv_b.weight |    576     |
# | blocks.1.multipathway_blocks.1.res_blocks.2.branch2.norm_b.weight |     8      |
# |  blocks.1.multipathway_blocks.1.res_blocks.2.branch2.norm_b.bias  |     8      |
# | blocks.1.multipathway_blocks.1.res_blocks.2.branch2.conv_c.weight |    256     |
# | blocks.1.multipathway_blocks.1.res_blocks.2.branch2.norm_c.weight |     32     |
# |  blocks.1.multipathway_blocks.1.res_blocks.2.branch2.norm_c.bias  |     32     |
# |       blocks.1.multipathway_fusion.conv_fast_to_slow.weight       |   14336    |
# |              blocks.1.multipathway_fusion.norm.weight             |     64     |
# |               blocks.1.multipathway_fusion.norm.bias              |     64     |
# |  blocks.2.multipathway_blocks.0.res_blocks.0.branch1_conv.weight  |   163840   |
# |  blocks.2.multipathway_blocks.0.res_blocks.0.branch1_norm.weight  |    512     |
# |   blocks.2.multipathway_blocks.0.res_blocks.0.branch1_norm.bias   |    512     |
# | blocks.2.multipathway_blocks.0.res_blocks.0.branch2.conv_a.weight |   40960    |
# | blocks.2.multipathway_blocks.0.res_blocks.0.branch2.norm_a.weight |    128     |
# |  blocks.2.multipathway_blocks.0.res_blocks.0.branch2.norm_a.bias  |    128     |
# | blocks.2.multipathway_blocks.0.res_blocks.0.branch2.conv_b.weight |   147456   |
# | blocks.2.multipathway_blocks.0.res_blocks.0.branch2.norm_b.weight |    128     |
# |  blocks.2.multipathway_blocks.0.res_blocks.0.branch2.norm_b.bias  |    128     |
# | blocks.2.multipathway_blocks.0.res_blocks.0.branch2.conv_c.weight |   65536    |
# | blocks.2.multipathway_blocks.0.res_blocks.0.branch2.norm_c.weight |    512     |
# |  blocks.2.multipathway_blocks.0.res_blocks.0.branch2.norm_c.bias  |    512     |
# | blocks.2.multipathway_blocks.0.res_blocks.1.branch2.conv_a.weight |   65536    |
# | blocks.2.multipathway_blocks.0.res_blocks.1.branch2.norm_a.weight |    128     |
# |  blocks.2.multipathway_blocks.0.res_blocks.1.branch2.norm_a.bias  |    128     |
# | blocks.2.multipathway_blocks.0.res_blocks.1.branch2.conv_b.weight |   147456   |
# | blocks.2.multipathway_blocks.0.res_blocks.1.branch2.norm_b.weight |    128     |
# |  blocks.2.multipathway_blocks.0.res_blocks.1.branch2.norm_b.bias  |    128     |
# | blocks.2.multipathway_blocks.0.res_blocks.1.branch2.conv_c.weight |   65536    |
# | blocks.2.multipathway_blocks.0.res_blocks.1.branch2.norm_c.weight |    512     |
# |  blocks.2.multipathway_blocks.0.res_blocks.1.branch2.norm_c.bias  |    512     |
# | blocks.2.multipathway_blocks.0.res_blocks.2.branch2.conv_a.weight |   65536    |
# | blocks.2.multipathway_blocks.0.res_blocks.2.branch2.norm_a.weight |    128     |
# |  blocks.2.multipathway_blocks.0.res_blocks.2.branch2.norm_a.bias  |    128     |
# | blocks.2.multipathway_blocks.0.res_blocks.2.branch2.conv_b.weight |   147456   |
# | blocks.2.multipathway_blocks.0.res_blocks.2.branch2.norm_b.weight |    128     |
# |  blocks.2.multipathway_blocks.0.res_blocks.2.branch2.norm_b.bias  |    128     |
# | blocks.2.multipathway_blocks.0.res_blocks.2.branch2.conv_c.weight |   65536    |
# | blocks.2.multipathway_blocks.0.res_blocks.2.branch2.norm_c.weight |    512     |
# |  blocks.2.multipathway_blocks.0.res_blocks.2.branch2.norm_c.bias  |    512     |
# | blocks.2.multipathway_blocks.0.res_blocks.3.branch2.conv_a.weight |   65536    |
# | blocks.2.multipathway_blocks.0.res_blocks.3.branch2.norm_a.weight |    128     |
# |  blocks.2.multipathway_blocks.0.res_blocks.3.branch2.norm_a.bias  |    128     |
# | blocks.2.multipathway_blocks.0.res_blocks.3.branch2.conv_b.weight |   147456   |
# | blocks.2.multipathway_blocks.0.res_blocks.3.branch2.norm_b.weight |    128     |
# |  blocks.2.multipathway_blocks.0.res_blocks.3.branch2.norm_b.bias  |    128     |
# | blocks.2.multipathway_blocks.0.res_blocks.3.branch2.conv_c.weight |   65536    |
# | blocks.2.multipathway_blocks.0.res_blocks.3.branch2.norm_c.weight |    512     |
# |  blocks.2.multipathway_blocks.0.res_blocks.3.branch2.norm_c.bias  |    512     |
# |  blocks.2.multipathway_blocks.1.res_blocks.0.branch1_conv.weight  |    2048    |
# |  blocks.2.multipathway_blocks.1.res_blocks.0.branch1_norm.weight  |     64     |
# |   blocks.2.multipathway_blocks.1.res_blocks.0.branch1_norm.bias   |     64     |
# | blocks.2.multipathway_blocks.1.res_blocks.0.branch2.conv_a.weight |    1536    |
# | blocks.2.multipathway_blocks.1.res_blocks.0.branch2.norm_a.weight |     16     |
# |  blocks.2.multipathway_blocks.1.res_blocks.0.branch2.norm_a.bias  |     16     |
# | blocks.2.multipathway_blocks.1.res_blocks.0.branch2.conv_b.weight |    2304    |
# | blocks.2.multipathway_blocks.1.res_blocks.0.branch2.norm_b.weight |     16     |
# |  blocks.2.multipathway_blocks.1.res_blocks.0.branch2.norm_b.bias  |     16     |
# | blocks.2.multipathway_blocks.1.res_blocks.0.branch2.conv_c.weight |    1024    |
# | blocks.2.multipathway_blocks.1.res_blocks.0.branch2.norm_c.weight |     64     |
# |  blocks.2.multipathway_blocks.1.res_blocks.0.branch2.norm_c.bias  |     64     |
# | blocks.2.multipathway_blocks.1.res_blocks.1.branch2.conv_a.weight |    3072    |
# | blocks.2.multipathway_blocks.1.res_blocks.1.branch2.norm_a.weight |     16     |
# |  blocks.2.multipathway_blocks.1.res_blocks.1.branch2.norm_a.bias  |     16     |
# | blocks.2.multipathway_blocks.1.res_blocks.1.branch2.conv_b.weight |    2304    |
# | blocks.2.multipathway_blocks.1.res_blocks.1.branch2.norm_b.weight |     16     |
# |  blocks.2.multipathway_blocks.1.res_blocks.1.branch2.norm_b.bias  |     16     |
# | blocks.2.multipathway_blocks.1.res_blocks.1.branch2.conv_c.weight |    1024    |
# | blocks.2.multipathway_blocks.1.res_blocks.1.branch2.norm_c.weight |     64     |
# |  blocks.2.multipathway_blocks.1.res_blocks.1.branch2.norm_c.bias  |     64     |
# | blocks.2.multipathway_blocks.1.res_blocks.2.branch2.conv_a.weight |    3072    |
# | blocks.2.multipathway_blocks.1.res_blocks.2.branch2.norm_a.weight |     16     |
# |  blocks.2.multipathway_blocks.1.res_blocks.2.branch2.norm_a.bias  |     16     |
# | blocks.2.multipathway_blocks.1.res_blocks.2.branch2.conv_b.weight |    2304    |
# | blocks.2.multipathway_blocks.1.res_blocks.2.branch2.norm_b.weight |     16     |
# |  blocks.2.multipathway_blocks.1.res_blocks.2.branch2.norm_b.bias  |     16     |
# | blocks.2.multipathway_blocks.1.res_blocks.2.branch2.conv_c.weight |    1024    |
# | blocks.2.multipathway_blocks.1.res_blocks.2.branch2.norm_c.weight |     64     |
# |  blocks.2.multipathway_blocks.1.res_blocks.2.branch2.norm_c.bias  |     64     |
# | blocks.2.multipathway_blocks.1.res_blocks.3.branch2.conv_a.weight |    3072    |
# | blocks.2.multipathway_blocks.1.res_blocks.3.branch2.norm_a.weight |     16     |
# |  blocks.2.multipathway_blocks.1.res_blocks.3.branch2.norm_a.bias  |     16     |
# | blocks.2.multipathway_blocks.1.res_blocks.3.branch2.conv_b.weight |    2304    |
# | blocks.2.multipathway_blocks.1.res_blocks.3.branch2.norm_b.weight |     16     |
# |  blocks.2.multipathway_blocks.1.res_blocks.3.branch2.norm_b.bias  |     16     |
# | blocks.2.multipathway_blocks.1.res_blocks.3.branch2.conv_c.weight |    1024    |
# | blocks.2.multipathway_blocks.1.res_blocks.3.branch2.norm_c.weight |     64     |
# |  blocks.2.multipathway_blocks.1.res_blocks.3.branch2.norm_c.bias  |     64     |
# |       blocks.2.multipathway_fusion.conv_fast_to_slow.weight       |   57344    |
# |              blocks.2.multipathway_fusion.norm.weight             |    128     |
# |               blocks.2.multipathway_fusion.norm.bias              |    128     |
# |  blocks.3.multipathway_blocks.0.res_blocks.0.branch1_conv.weight  |   655360   |
# |  blocks.3.multipathway_blocks.0.res_blocks.0.branch1_norm.weight  |    1024    |
# |   blocks.3.multipathway_blocks.0.res_blocks.0.branch1_norm.bias   |    1024    |
# | blocks.3.multipathway_blocks.0.res_blocks.0.branch2.conv_a.weight |   491520   |
# | blocks.3.multipathway_blocks.0.res_blocks.0.branch2.norm_a.weight |    256     |
# |  blocks.3.multipathway_blocks.0.res_blocks.0.branch2.norm_a.bias  |    256     |
# | blocks.3.multipathway_blocks.0.res_blocks.0.branch2.conv_b.weight |   589824   |
# | blocks.3.multipathway_blocks.0.res_blocks.0.branch2.norm_b.weight |    256     |
# |  blocks.3.multipathway_blocks.0.res_blocks.0.branch2.norm_b.bias  |    256     |
# | blocks.3.multipathway_blocks.0.res_blocks.0.branch2.conv_c.weight |   262144   |
# | blocks.3.multipathway_blocks.0.res_blocks.0.branch2.norm_c.weight |    1024    |
# |  blocks.3.multipathway_blocks.0.res_blocks.0.branch2.norm_c.bias  |    1024    |
# | blocks.3.multipathway_blocks.0.res_blocks.1.branch2.conv_a.weight |   786432   |
# | blocks.3.multipathway_blocks.0.res_blocks.1.branch2.norm_a.weight |    256     |
# |  blocks.3.multipathway_blocks.0.res_blocks.1.branch2.norm_a.bias  |    256     |
# | blocks.3.multipathway_blocks.0.res_blocks.1.branch2.conv_b.weight |   589824   |
# | blocks.3.multipathway_blocks.0.res_blocks.1.branch2.norm_b.weight |    256     |
# |  blocks.3.multipathway_blocks.0.res_blocks.1.branch2.norm_b.bias  |    256     |
# | blocks.3.multipathway_blocks.0.res_blocks.1.branch2.conv_c.weight |   262144   |
# | blocks.3.multipathway_blocks.0.res_blocks.1.branch2.norm_c.weight |    1024    |
# |  blocks.3.multipathway_blocks.0.res_blocks.1.branch2.norm_c.bias  |    1024    |
# | blocks.3.multipathway_blocks.0.res_blocks.2.branch2.conv_a.weight |   786432   |
# | blocks.3.multipathway_blocks.0.res_blocks.2.branch2.norm_a.weight |    256     |
# |  blocks.3.multipathway_blocks.0.res_blocks.2.branch2.norm_a.bias  |    256     |
# | blocks.3.multipathway_blocks.0.res_blocks.2.branch2.conv_b.weight |   589824   |
# | blocks.3.multipathway_blocks.0.res_blocks.2.branch2.norm_b.weight |    256     |
# |  blocks.3.multipathway_blocks.0.res_blocks.2.branch2.norm_b.bias  |    256     |
# | blocks.3.multipathway_blocks.0.res_blocks.2.branch2.conv_c.weight |   262144   |
# | blocks.3.multipathway_blocks.0.res_blocks.2.branch2.norm_c.weight |    1024    |
# |  blocks.3.multipathway_blocks.0.res_blocks.2.branch2.norm_c.bias  |    1024    |
# | blocks.3.multipathway_blocks.0.res_blocks.3.branch2.conv_a.weight |   786432   |
# | blocks.3.multipathway_blocks.0.res_blocks.3.branch2.norm_a.weight |    256     |
# |  blocks.3.multipathway_blocks.0.res_blocks.3.branch2.norm_a.bias  |    256     |
# | blocks.3.multipathway_blocks.0.res_blocks.3.branch2.conv_b.weight |   589824   |
# | blocks.3.multipathway_blocks.0.res_blocks.3.branch2.norm_b.weight |    256     |
# |  blocks.3.multipathway_blocks.0.res_blocks.3.branch2.norm_b.bias  |    256     |
# | blocks.3.multipathway_blocks.0.res_blocks.3.branch2.conv_c.weight |   262144   |
# | blocks.3.multipathway_blocks.0.res_blocks.3.branch2.norm_c.weight |    1024    |
# |  blocks.3.multipathway_blocks.0.res_blocks.3.branch2.norm_c.bias  |    1024    |
# | blocks.3.multipathway_blocks.0.res_blocks.4.branch2.conv_a.weight |   786432   |
# | blocks.3.multipathway_blocks.0.res_blocks.4.branch2.norm_a.weight |    256     |
# |  blocks.3.multipathway_blocks.0.res_blocks.4.branch2.norm_a.bias  |    256     |
# | blocks.3.multipathway_blocks.0.res_blocks.4.branch2.conv_b.weight |   589824   |
# | blocks.3.multipathway_blocks.0.res_blocks.4.branch2.norm_b.weight |    256     |
# |  blocks.3.multipathway_blocks.0.res_blocks.4.branch2.norm_b.bias  |    256     |
# | blocks.3.multipathway_blocks.0.res_blocks.4.branch2.conv_c.weight |   262144   |
# | blocks.3.multipathway_blocks.0.res_blocks.4.branch2.norm_c.weight |    1024    |
# |  blocks.3.multipathway_blocks.0.res_blocks.4.branch2.norm_c.bias  |    1024    |
# | blocks.3.multipathway_blocks.0.res_blocks.5.branch2.conv_a.weight |   786432   |
# | blocks.3.multipathway_blocks.0.res_blocks.5.branch2.norm_a.weight |    256     |
# |  blocks.3.multipathway_blocks.0.res_blocks.5.branch2.norm_a.bias  |    256     |
# | blocks.3.multipathway_blocks.0.res_blocks.5.branch2.conv_b.weight |   589824   |
# | blocks.3.multipathway_blocks.0.res_blocks.5.branch2.norm_b.weight |    256     |
# |  blocks.3.multipathway_blocks.0.res_blocks.5.branch2.norm_b.bias  |    256     |
# | blocks.3.multipathway_blocks.0.res_blocks.5.branch2.conv_c.weight |   262144   |
# | blocks.3.multipathway_blocks.0.res_blocks.5.branch2.norm_c.weight |    1024    |
# |  blocks.3.multipathway_blocks.0.res_blocks.5.branch2.norm_c.bias  |    1024    |
# |  blocks.3.multipathway_blocks.1.res_blocks.0.branch1_conv.weight  |    8192    |
# |  blocks.3.multipathway_blocks.1.res_blocks.0.branch1_norm.weight  |    128     |
# |   blocks.3.multipathway_blocks.1.res_blocks.0.branch1_norm.bias   |    128     |
# | blocks.3.multipathway_blocks.1.res_blocks.0.branch2.conv_a.weight |    6144    |
# | blocks.3.multipathway_blocks.1.res_blocks.0.branch2.norm_a.weight |     32     |
# |  blocks.3.multipathway_blocks.1.res_blocks.0.branch2.norm_a.bias  |     32     |
# | blocks.3.multipathway_blocks.1.res_blocks.0.branch2.conv_b.weight |    9216    |
# | blocks.3.multipathway_blocks.1.res_blocks.0.branch2.norm_b.weight |     32     |
# |  blocks.3.multipathway_blocks.1.res_blocks.0.branch2.norm_b.bias  |     32     |
# | blocks.3.multipathway_blocks.1.res_blocks.0.branch2.conv_c.weight |    4096    |
# | blocks.3.multipathway_blocks.1.res_blocks.0.branch2.norm_c.weight |    128     |
# |  blocks.3.multipathway_blocks.1.res_blocks.0.branch2.norm_c.bias  |    128     |
# | blocks.3.multipathway_blocks.1.res_blocks.1.branch2.conv_a.weight |   12288    |
# | blocks.3.multipathway_blocks.1.res_blocks.1.branch2.norm_a.weight |     32     |
# |  blocks.3.multipathway_blocks.1.res_blocks.1.branch2.norm_a.bias  |     32     |
# | blocks.3.multipathway_blocks.1.res_blocks.1.branch2.conv_b.weight |    9216    |
# | blocks.3.multipathway_blocks.1.res_blocks.1.branch2.norm_b.weight |     32     |
# |  blocks.3.multipathway_blocks.1.res_blocks.1.branch2.norm_b.bias  |     32     |
# | blocks.3.multipathway_blocks.1.res_blocks.1.branch2.conv_c.weight |    4096    |
# | blocks.3.multipathway_blocks.1.res_blocks.1.branch2.norm_c.weight |    128     |
# |  blocks.3.multipathway_blocks.1.res_blocks.1.branch2.norm_c.bias  |    128     |
# | blocks.3.multipathway_blocks.1.res_blocks.2.branch2.conv_a.weight |   12288    |
# | blocks.3.multipathway_blocks.1.res_blocks.2.branch2.norm_a.weight |     32     |
# |  blocks.3.multipathway_blocks.1.res_blocks.2.branch2.norm_a.bias  |     32     |
# | blocks.3.multipathway_blocks.1.res_blocks.2.branch2.conv_b.weight |    9216    |
# | blocks.3.multipathway_blocks.1.res_blocks.2.branch2.norm_b.weight |     32     |
# |  blocks.3.multipathway_blocks.1.res_blocks.2.branch2.norm_b.bias  |     32     |
# | blocks.3.multipathway_blocks.1.res_blocks.2.branch2.conv_c.weight |    4096    |
# | blocks.3.multipathway_blocks.1.res_blocks.2.branch2.norm_c.weight |    128     |
# |  blocks.3.multipathway_blocks.1.res_blocks.2.branch2.norm_c.bias  |    128     |
# | blocks.3.multipathway_blocks.1.res_blocks.3.branch2.conv_a.weight |   12288    |
# | blocks.3.multipathway_blocks.1.res_blocks.3.branch2.norm_a.weight |     32     |
# |  blocks.3.multipathway_blocks.1.res_blocks.3.branch2.norm_a.bias  |     32     |
# | blocks.3.multipathway_blocks.1.res_blocks.3.branch2.conv_b.weight |    9216    |
# | blocks.3.multipathway_blocks.1.res_blocks.3.branch2.norm_b.weight |     32     |
# |  blocks.3.multipathway_blocks.1.res_blocks.3.branch2.norm_b.bias  |     32     |
# | blocks.3.multipathway_blocks.1.res_blocks.3.branch2.conv_c.weight |    4096    |
# | blocks.3.multipathway_blocks.1.res_blocks.3.branch2.norm_c.weight |    128     |
# |  blocks.3.multipathway_blocks.1.res_blocks.3.branch2.norm_c.bias  |    128     |
# | blocks.3.multipathway_blocks.1.res_blocks.4.branch2.conv_a.weight |   12288    |
# | blocks.3.multipathway_blocks.1.res_blocks.4.branch2.norm_a.weight |     32     |
# |  blocks.3.multipathway_blocks.1.res_blocks.4.branch2.norm_a.bias  |     32     |
# | blocks.3.multipathway_blocks.1.res_blocks.4.branch2.conv_b.weight |    9216    |
# | blocks.3.multipathway_blocks.1.res_blocks.4.branch2.norm_b.weight |     32     |
# |  blocks.3.multipathway_blocks.1.res_blocks.4.branch2.norm_b.bias  |     32     |
# | blocks.3.multipathway_blocks.1.res_blocks.4.branch2.conv_c.weight |    4096    |
# | blocks.3.multipathway_blocks.1.res_blocks.4.branch2.norm_c.weight |    128     |
# |  blocks.3.multipathway_blocks.1.res_blocks.4.branch2.norm_c.bias  |    128     |
# | blocks.3.multipathway_blocks.1.res_blocks.5.branch2.conv_a.weight |   12288    |
# | blocks.3.multipathway_blocks.1.res_blocks.5.branch2.norm_a.weight |     32     |
# |  blocks.3.multipathway_blocks.1.res_blocks.5.branch2.norm_a.bias  |     32     |
# | blocks.3.multipathway_blocks.1.res_blocks.5.branch2.conv_b.weight |    9216    |
# | blocks.3.multipathway_blocks.1.res_blocks.5.branch2.norm_b.weight |     32     |
# |  blocks.3.multipathway_blocks.1.res_blocks.5.branch2.norm_b.bias  |     32     |
# | blocks.3.multipathway_blocks.1.res_blocks.5.branch2.conv_c.weight |    4096    |
# | blocks.3.multipathway_blocks.1.res_blocks.5.branch2.norm_c.weight |    128     |
# |  blocks.3.multipathway_blocks.1.res_blocks.5.branch2.norm_c.bias  |    128     |
# |       blocks.3.multipathway_fusion.conv_fast_to_slow.weight       |   229376   |
# |              blocks.3.multipathway_fusion.norm.weight             |    256     |
# |               blocks.3.multipathway_fusion.norm.bias              |    256     |
# |  blocks.4.multipathway_blocks.0.res_blocks.0.branch1_conv.weight  |  2621440   |
# |  blocks.4.multipathway_blocks.0.res_blocks.0.branch1_norm.weight  |    2048    |
# |   blocks.4.multipathway_blocks.0.res_blocks.0.branch1_norm.bias   |    2048    |
# | blocks.4.multipathway_blocks.0.res_blocks.0.branch2.conv_a.weight |  1966080   |
# | blocks.4.multipathway_blocks.0.res_blocks.0.branch2.norm_a.weight |    512     |
# |  blocks.4.multipathway_blocks.0.res_blocks.0.branch2.norm_a.bias  |    512     |
# | blocks.4.multipathway_blocks.0.res_blocks.0.branch2.conv_b.weight |  2359296   |
# | blocks.4.multipathway_blocks.0.res_blocks.0.branch2.norm_b.weight |    512     |
# |  blocks.4.multipathway_blocks.0.res_blocks.0.branch2.norm_b.bias  |    512     |
# | blocks.4.multipathway_blocks.0.res_blocks.0.branch2.conv_c.weight |  1048576   |
# | blocks.4.multipathway_blocks.0.res_blocks.0.branch2.norm_c.weight |    2048    |
# |  blocks.4.multipathway_blocks.0.res_blocks.0.branch2.norm_c.bias  |    2048    |
# | blocks.4.multipathway_blocks.0.res_blocks.1.branch2.conv_a.weight |  3145728   |
# | blocks.4.multipathway_blocks.0.res_blocks.1.branch2.norm_a.weight |    512     |
# |  blocks.4.multipathway_blocks.0.res_blocks.1.branch2.norm_a.bias  |    512     |
# | blocks.4.multipathway_blocks.0.res_blocks.1.branch2.conv_b.weight |  2359296   |
# | blocks.4.multipathway_blocks.0.res_blocks.1.branch2.norm_b.weight |    512     |
# |  blocks.4.multipathway_blocks.0.res_blocks.1.branch2.norm_b.bias  |    512     |
# | blocks.4.multipathway_blocks.0.res_blocks.1.branch2.conv_c.weight |  1048576   |
# | blocks.4.multipathway_blocks.0.res_blocks.1.branch2.norm_c.weight |    2048    |
# |  blocks.4.multipathway_blocks.0.res_blocks.1.branch2.norm_c.bias  |    2048    |
# | blocks.4.multipathway_blocks.0.res_blocks.2.branch2.conv_a.weight |  3145728   |
# | blocks.4.multipathway_blocks.0.res_blocks.2.branch2.norm_a.weight |    512     |
# |  blocks.4.multipathway_blocks.0.res_blocks.2.branch2.norm_a.bias  |    512     |
# | blocks.4.multipathway_blocks.0.res_blocks.2.branch2.conv_b.weight |  2359296   |
# | blocks.4.multipathway_blocks.0.res_blocks.2.branch2.norm_b.weight |    512     |
# |  blocks.4.multipathway_blocks.0.res_blocks.2.branch2.norm_b.bias  |    512     |
# | blocks.4.multipathway_blocks.0.res_blocks.2.branch2.conv_c.weight |  1048576   |
# | blocks.4.multipathway_blocks.0.res_blocks.2.branch2.norm_c.weight |    2048    |
# |  blocks.4.multipathway_blocks.0.res_blocks.2.branch2.norm_c.bias  |    2048    |
# |  blocks.4.multipathway_blocks.1.res_blocks.0.branch1_conv.weight  |   32768    |
# |  blocks.4.multipathway_blocks.1.res_blocks.0.branch1_norm.weight  |    256     |
# |   blocks.4.multipathway_blocks.1.res_blocks.0.branch1_norm.bias   |    256     |
# | blocks.4.multipathway_blocks.1.res_blocks.0.branch2.conv_a.weight |   24576    |
# | blocks.4.multipathway_blocks.1.res_blocks.0.branch2.norm_a.weight |     64     |
# |  blocks.4.multipathway_blocks.1.res_blocks.0.branch2.norm_a.bias  |     64     |
# | blocks.4.multipathway_blocks.1.res_blocks.0.branch2.conv_b.weight |   36864    |
# | blocks.4.multipathway_blocks.1.res_blocks.0.branch2.norm_b.weight |     64     |
# |  blocks.4.multipathway_blocks.1.res_blocks.0.branch2.norm_b.bias  |     64     |
# | blocks.4.multipathway_blocks.1.res_blocks.0.branch2.conv_c.weight |   16384    |
# | blocks.4.multipathway_blocks.1.res_blocks.0.branch2.norm_c.weight |    256     |
# |  blocks.4.multipathway_blocks.1.res_blocks.0.branch2.norm_c.bias  |    256     |
# | blocks.4.multipathway_blocks.1.res_blocks.1.branch2.conv_a.weight |   49152    |
# | blocks.4.multipathway_blocks.1.res_blocks.1.branch2.norm_a.weight |     64     |
# |  blocks.4.multipathway_blocks.1.res_blocks.1.branch2.norm_a.bias  |     64     |
# | blocks.4.multipathway_blocks.1.res_blocks.1.branch2.conv_b.weight |   36864    |
# | blocks.4.multipathway_blocks.1.res_blocks.1.branch2.norm_b.weight |     64     |
# |  blocks.4.multipathway_blocks.1.res_blocks.1.branch2.norm_b.bias  |     64     |
# | blocks.4.multipathway_blocks.1.res_blocks.1.branch2.conv_c.weight |   16384    |
# | blocks.4.multipathway_blocks.1.res_blocks.1.branch2.norm_c.weight |    256     |
# |  blocks.4.multipathway_blocks.1.res_blocks.1.branch2.norm_c.bias  |    256     |
# | blocks.4.multipathway_blocks.1.res_blocks.2.branch2.conv_a.weight |   49152    |
# | blocks.4.multipathway_blocks.1.res_blocks.2.branch2.norm_a.weight |     64     |
# |  blocks.4.multipathway_blocks.1.res_blocks.2.branch2.norm_a.bias  |     64     |
# | blocks.4.multipathway_blocks.1.res_blocks.2.branch2.conv_b.weight |   36864    |
# | blocks.4.multipathway_blocks.1.res_blocks.2.branch2.norm_b.weight |     64     |
# |  blocks.4.multipathway_blocks.1.res_blocks.2.branch2.norm_b.bias  |     64     |
# | blocks.4.multipathway_blocks.1.res_blocks.2.branch2.conv_c.weight |   16384    |
# | blocks.4.multipathway_blocks.1.res_blocks.2.branch2.norm_c.weight |    256     |
# |  blocks.4.multipathway_blocks.1.res_blocks.2.branch2.norm_c.bias  |    256     |
# |                        blocks.6.proj.weight                       |   921600   |
# |                         blocks.6.proj.bias                        |    400     |
# +-------------------------------------------------------------------+------------+
# Total Trainable Params: 34566488
# 34566488

# %%
print(model)
# Out:
# Net(
#   (blocks): ModuleList(
#     (0): MultiPathWayWithFuse(
#       (multipathway_blocks): ModuleList(
#         (0): ResNetBasicStem(
#           (conv): Conv3d(3, 64, kernel_size=(1, 7, 7), stride=(1, 2, 2), padding=(0, 3, 3), bias=False)
#           (norm): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activation): ReLU()
#           (pool): MaxPool3d(kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=[0, 1, 1], dilation=1, ceil_mode=False)
#         )
#         (1): ResNetBasicStem(
#           (conv): Conv3d(3, 8, kernel_size=(5, 7, 7), stride=(1, 2, 2), padding=(2, 3, 3), bias=False)
#           (norm): BatchNorm3d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activation): ReLU()
#           (pool): MaxPool3d(kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=[0, 1, 1], dilation=1, ceil_mode=False)
#         )
#       )
#       (multipathway_fusion): FuseFastToSlow(
#         (conv_fast_to_slow): Conv3d(8, 16, kernel_size=(7, 1, 1), stride=(4, 1, 1), padding=(3, 0, 0), bias=False)
#         (norm): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activation): ReLU()
#       )
#     )
#     (1): MultiPathWayWithFuse(
#       (multipathway_blocks): ModuleList(
#         (0): ResStage(
#           (res_blocks): ModuleList(
#             (0): ResBlock(
#               (branch1_conv): Conv3d(80, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#               (branch1_norm): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(80, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_a): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#             (1): ResBlock(
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(256, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_a): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#             (2): ResBlock(
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(256, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_a): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#           )
#         )
#         (1): ResStage(
#           (res_blocks): ModuleList(
#             (0): ResBlock(
#               (branch1_conv): Conv3d(8, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#               (branch1_norm): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(8, 8, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#                 (norm_a): BatchNorm3d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(8, 8, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(8, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#             (1): ResBlock(
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(32, 8, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#                 (norm_a): BatchNorm3d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(8, 8, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(8, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#             (2): ResBlock(
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(32, 8, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#                 (norm_a): BatchNorm3d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(8, 8, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(8, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#           )
#         )
#       )
#       (multipathway_fusion): FuseFastToSlow(
#         (conv_fast_to_slow): Conv3d(32, 64, kernel_size=(7, 1, 1), stride=(4, 1, 1), padding=(3, 0, 0), bias=False)
#         (norm): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activation): ReLU()
#       )
#     )
#     (2): MultiPathWayWithFuse(
#       (multipathway_blocks): ModuleList(
#         (0): ResStage(
#           (res_blocks): ModuleList(
#             (0): ResBlock(
#               (branch1_conv): Conv3d(320, 512, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#               (branch1_norm): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(320, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_a): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#             (1): ResBlock(
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_a): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#             (2): ResBlock(
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_a): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#             (3): ResBlock(
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(512, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_a): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(128, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#           )
#         )
#         (1): ResStage(
#           (res_blocks): ModuleList(
#             (0): ResBlock(
#               (branch1_conv): Conv3d(32, 64, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#               (branch1_norm): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(32, 16, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#                 (norm_a): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(16, 16, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(16, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#             (1): ResBlock(
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(64, 16, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#                 (norm_a): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(16, 16, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(16, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#             (2): ResBlock(
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(64, 16, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#                 (norm_a): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(16, 16, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(16, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#             (3): ResBlock(
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(64, 16, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#                 (norm_a): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(16, 16, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(16, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#           )
#         )
#       )
#       (multipathway_fusion): FuseFastToSlow(
#         (conv_fast_to_slow): Conv3d(64, 128, kernel_size=(7, 1, 1), stride=(4, 1, 1), padding=(3, 0, 0), bias=False)
#         (norm): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activation): ReLU()
#       )
#     )
#     (3): MultiPathWayWithFuse(
#       (multipathway_blocks): ModuleList(
#         (0): ResStage(
#           (res_blocks): ModuleList(
#             (0): ResBlock(
#               (branch1_conv): Conv3d(640, 1024, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#               (branch1_norm): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(640, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#                 (norm_a): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#             (1): ResBlock(
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#                 (norm_a): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#             (2): ResBlock(
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#                 (norm_a): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#             (3): ResBlock(
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#                 (norm_a): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#             (4): ResBlock(
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#                 (norm_a): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#             (5): ResBlock(
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(1024, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#                 (norm_a): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(256, 256, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(256, 1024, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#           )
#         )
#         (1): ResStage(
#           (res_blocks): ModuleList(
#             (0): ResBlock(
#               (branch1_conv): Conv3d(64, 128, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#               (branch1_norm): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(64, 32, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#                 (norm_a): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(32, 32, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(32, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#             (1): ResBlock(
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(128, 32, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#                 (norm_a): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(32, 32, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(32, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#             (2): ResBlock(
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(128, 32, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#                 (norm_a): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(32, 32, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(32, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#             (3): ResBlock(
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(128, 32, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#                 (norm_a): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(32, 32, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(32, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#             (4): ResBlock(
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(128, 32, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#                 (norm_a): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(32, 32, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(32, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#             (5): ResBlock(
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(128, 32, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#                 (norm_a): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(32, 32, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(32, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#           )
#         )
#       )
#       (multipathway_fusion): FuseFastToSlow(
#         (conv_fast_to_slow): Conv3d(128, 256, kernel_size=(7, 1, 1), stride=(4, 1, 1), padding=(3, 0, 0), bias=False)
#         (norm): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (activation): ReLU()
#       )
#     )
#     (4): MultiPathWayWithFuse(
#       (multipathway_blocks): ModuleList(
#         (0): ResStage(
#           (res_blocks): ModuleList(
#             (0): ResBlock(
#               (branch1_conv): Conv3d(1280, 2048, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#               (branch1_norm): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(1280, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#                 (norm_a): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(512, 512, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#             (1): ResBlock(
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(2048, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#                 (norm_a): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(512, 512, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#             (2): ResBlock(
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(2048, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#                 (norm_a): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(512, 512, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(512, 2048, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#           )
#         )
#         (1): ResStage(
#           (res_blocks): ModuleList(
#             (0): ResBlock(
#               (branch1_conv): Conv3d(128, 256, kernel_size=(1, 1, 1), stride=(1, 2, 2), bias=False)
#               (branch1_norm): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(128, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#                 (norm_a): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#             (1): ResBlock(
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(256, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#                 (norm_a): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#             (2): ResBlock(
#               (branch2): BottleneckBlock(
#                 (conv_a): Conv3d(256, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#                 (norm_a): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_a): ReLU()
#                 (conv_b): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#                 (norm_b): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (act_b): ReLU()
#                 (conv_c): Conv3d(64, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#                 (norm_c): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (activation): ReLU()
#             )
#           )
#         )
#       )
#       (multipathway_fusion): Identity()
#     )
#     (5): PoolConcatPathway(
#       (pool): ModuleList(
#         (0): AvgPool3d(kernel_size=(8, 7, 7), stride=(1, 1, 1), padding=(0, 0, 0))
#         (1): AvgPool3d(kernel_size=(32, 7, 7), stride=(1, 1, 1), padding=(0, 0, 0))
#       )
#     )
#     (6): ResNetBasicHead(
#       (dropout): Dropout(p=0.5, inplace=False)
#       (proj): Linear(in_features=2304, out_features=400, bias=True)
#       (output_pool): AdaptiveAvgPool3d(output_size=1)
#     )
#   )
# )

# %%
from torchvision import models
from torchsummary import summary


# vgg = models.vgg16()
summary(model, input , batch_size=-1, device='cpu')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-98288a649db1> in <module>
#       4
#       5 # vgg = models.vgg16()
# ----> 6 summary(model, input , batch_size=-1, device='cpu')
#
# /usr/local/lib/python3.8/dist-packages/torchsummary/torchsummary.py in summary(model, input_size, batch_size, device)
#      58
#      59     # batch_size of 2 for batchnorm
# ---> 60     x = [torch.rand(2, *in_size).type(dtype) for in_size in input_size]
#      61     # print(type(x[0]))
#      62
#
# TypeError: 'method' object is not iterable

# %%
module = model.blocks
print(list(module.named_parameters()))
# prune.random_unstructured(module, name="weight", amount=0.3)
# Out:
#   File "<ipython-input-17-132bddd60093>", line 1
#     module = model.blocks.0.multipathway_blocks.0.conv
#                          ^
# SyntaxError: invalid syntax
